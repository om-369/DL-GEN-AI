# %% [markdown]
# <a href="https://colab.research.google.com/github/om-369/DL-GEN-AI/blob/main/Bi_directional_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#RNN --> recurrent neural network

# %%
#advantages of RNN over ANN

# handle sequential data
# handle variable length input/output

# %%
from IPython.display import Image, display

# %%
display(Image("/content/rnn vs ann.jpg"))

# %%
"this movies is great"

"yeh movie acchi hai"

# %%
at time step 1 --> this    --> hidden state is stored
at time step 2 --> movies  -->

# %%
display(Image("/content/Unrolled-RNN.jpg"))

# %%
at t= 1

h1 = Wxh * X1 + h0   ---> h0 is zero or randomly initialized

h2 = Wxh * X2 + h1


h3 = Wxh * X3 + h2


h100 =  Wxh * X100 + h99

# %%
"this movies is great"

# %%
[]

# %%
#types of RNN

one to one
one to many
many to one  --> sentiment analysis
many to many  -->
same length >> pos
variable length  >> translation

# %%
display(Image("/content/rnn2.png"))

# %%
many to many --> encoder-decoder

# %%
#Advantages of RNN

1) can process sequential data
2) can handle variable length input
3) even after input size increases, model size remain same

# %%
#Limitations of RNN

1) vanishing/exploding gradient
2) unable to process long sequences
3) not able to get future context
4) complexity of model and resources

# %%
Apple is a great company

Apple is my favourite fruit

# %% [markdown]
# ##Bi-directional RNN

# %%
display(Image("/content/bidirectional RNN.png", width=800))
